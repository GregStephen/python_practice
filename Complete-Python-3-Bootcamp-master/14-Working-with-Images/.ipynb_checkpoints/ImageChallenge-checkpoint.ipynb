# %%
from PIL import Image

# %%
matrix = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
big_mask = mask.resize((1015,559))

# %%
big_mask.putalpha(128)

# %%
matrix.putalpha(128)

# %%
matrix.paste(im=big_mask, box=(0,0), mask=big_mask)

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1E92E772308>
